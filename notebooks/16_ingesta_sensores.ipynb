# %% [markdown]
# # WP1.1: Ingesta y Limpieza de Sensores (Issue #16)
#
# **Asignados:** ivanloki00, Juanjocepe05
# **Dificultad:** 5/10
#
# ### Descripción
# Este es el primer paso crítico del proyecto. Necesitamos transformar los datos brutos de los 40 sensores de Liverpool en un dataset limpio, estandarizado y listo para el análisis temporal (Juanjo) y el modelado espacial (Ivan). Los sensores registran partículas PM2.5 y PM10 en intervalos de aproximadamente 30 minutos.

# %% [markdown]
# ## Paso 1: Descarga e Inspección
# Acceder a la carpeta `../data/raw/DatosCompletos` y explorar la estructura de los CSVs.

# %%
import pandas as pd
import os

# TODO: Tu código aquí para listar o inspeccionar los archivos

# %% [markdown]
# ## Paso 2: Unificación de Datos
# Carga todos los archivos CSV de la carpeta `DatosCompletos` y unifícalos en un solo DataFrame.

# %%
# TODO: Escribe el código para leer y concatenar los CSVs. 
# Sugerencia: Puedes usar un for loop con os.listdir y pd.concat

# %% [markdown]
# ## Paso 3: Estandarización Temporal
# Convierte todas las marcas de tiempo a un formato datetime único y asegúrate de que los intervalos de 30 minutos sean coherentes.

# %%
# TODO: Usa pd.to_datetime en la columna de fecha/hora.
# Considera redondear tiempos irregulares (ej. dt.round('30min'))

# %% [markdown]
# ## Paso 4: Control de Calidad
# - Identificar y tratar valores nulos.
# - Detectar y filtrar outliers (lecturas físicamente imposibles o errores de sensor).
# - Gestionar posibles duplicados.

# %%
# TODO: 
# 1. Revisa si hay nulos (df.isnull().sum()) y decide cómo tratarlos.
# 2. Revisa la distribución de PM2.5 y PM10 (df.describe()). Si hay valores negativos o absurdamente altos, quítalos o analízalos.
# 3. Revisa y elimina filas duplicadas si las hay.

# %% [markdown]
# ## Paso 5: Asociación Geoespacial
# Vincula cada lectura de sensor con sus coordenadas exactas de ubicación usando el archivo de coordenadas base.

# %%
# TODO: Carga `../data/raw/CoordsSensores.csv`
# Realiza un 'merge' o 'join' con el dataframe limpio basándote en el ID del sensor.

# %% [markdown]
# ## Paso 6: Exportación
# Genera el archivo `sensors_cleaned.csv` estructurado final.

# %%
# TODO: Guarda el dataframe final en la carpeta correspondiente
# df.to_csv('../data/processed/sensors_cleaned.csv', index=False)
